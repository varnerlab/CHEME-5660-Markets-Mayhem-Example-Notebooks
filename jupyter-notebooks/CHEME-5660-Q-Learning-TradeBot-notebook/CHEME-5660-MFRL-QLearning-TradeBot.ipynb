# %% [markdown]
# ## CHEME 5660: Building a Trading Bot using Model-Free Reinforcement Learning

# %% [markdown]
# ### Introduction
# In this example we'll use [Q-learning](https://en.wikipedia.org/wiki/Q-learning), a model-free reinforcement learning approach, to In this example, we'll use [Q-learning](https://en.wikipedia.org/wiki/Q-learning), a model-free reinforcement learning approach, to build a trading bot for stocks in the `CHEME-5660 portfolio`. In particular, we've downloaded `5 min` Open High Low Close (OHLC) data for the 150 tickers in the `CHEME 5660 portfolio` from [Polygon.io](https://polygon.io). From this data, we'll use the Q-learning approach from [Chapter 17 of Kochenderfer et al. (2022)](https://algorithmsbook.com) to estimate the $Q(s, a)$ table; once we have the $Q(s, a)$ table, we can estimate the policy $\pi(s)$:
#
# $$\pi(s) = \text{arg}\max_{a}Q(s,a)$$
#
# We estimate the $Q(s,a)$ table through experimentation, where we update $Q(s,a)$ after each experiment using the update rule:
#
# $$Q(s,a)\leftarrow{Q(s,a)}+\alpha\left(r+\gamma\max_{a^{\prime}}Q(s^{\prime},a^{\prime}) - Q(s,a)\right)$$
#
# Background reading/viewing on Reinforcement Learning and Model-free Reinforcement Learning:
# * [Chapter 17: Mykel J. Kochenderfer, Tim A. Wheeler, Kyle H. Wray "Algorithms for Decision Making", MIT Press 2022](https://algorithmsbook.com)
# * [Stanford CS234: Reinforcement Learning (2019), Lecture 4](https://www.youtube.com/playlist?list=PLoROMvodv4rOSOPzutgyCTapiGlY2Nd8u)
# * [Stanford CS221: Artificial Intelligence: Principles and Techniques (2019), Lecture 8](https://www.youtube.com/playlist?list=PLoROMvodv4rO1NB9TD4iUZ3qghGEGtqNX)

# %% [markdown]
# ### Example setup

# %%
import Pkg; Pkg.activate("."); Pkg.resolve(); Pkg.instantiate();
# Out:
#   Activating project at `~/Desktop/julia_work/CHEME-5660-Markets-Mayhem-Example-Notebooks/jupyter-notebooks/CHEME-5660-Q-Learning-TradeBot-notebook`
#   No Changes to `~/Desktop/julia_work/CHEME-5660-Markets-Mayhem-Example-Notebooks/jupyter-notebooks/CHEME-5660-Q-Learning-TradeBot-notebook/Project.toml`
#   No Changes to `~/Desktop/julia_work/CHEME-5660-Markets-Mayhem-Example-Notebooks/jupyter-notebooks/CHEME-5660-Q-Learning-TradeBot-notebook/Manifest.toml`

# %%
# load req packages -
using DataFrames
using Dates
using FileIO
using JLD2
using PrettyTables
using Distributions
using Statistics
using DataFrames
using Plots
using Colors
using MLJLinearModels

# setup paths -
const _ROOT = pwd();
const _PATH_TO_DATA = joinpath(_ROOT, "data");

# %% [markdown]
# #### Load the example code library
# The call to the `include` function loads the `CHEME-5660-Example-CodeLib.jl` library into the notebook; this library contains types and functions we use during the example. In particular, we encode the online $Q(s,a)$ update routine listed as `Algorithm 17.2` from [Kochenderfer et al (2022)](https://algorithmsbook.com).

# %%
include("CHEME-5660-Example-CodeLib.jl");

# %% [markdown]
# ### Setup constants and other resources

# %% [markdown]
# #### Load and partition the OHLC price data set
# This data is `5 min` data, meaning we have Open High Low Close (OHLC) data for the 150 tickers in the `CHEME 5660 portfolio` every five minutes for one week of trading days. We'll use this data to estimate the trade policy of our agent.

# %%
# what ticker do we want to explore?
ticker_symbol = "AMD";

# load the JLD2 portfolio data file -
price_data_dictionary = load(joinpath(_PATH_TO_DATA, "CHEME-5660-Portfolio-Q-learning-5min-11-20-22.jld2"))["dd"];

# we have these ticker symbols in our data set -
ticker_symbol_array = sort(keys(price_data_dictionary) |> collect);

# Partition the data into a training and prediction set
(price_training_dict, price_prediction_dict) = partition(price_data_dictionary; fraction=0.90);

# this version uses all the data for training -
# df_training = price_data_dictionary[ticker_symbol];

# this version uses only some of the data for training 
df_training = price_training_dict[ticker_symbol];
df_prediction = price_prediction_dict[ticker_symbol];

# %% [markdown]
# ##### Constants

# %%
# how many days of historical data are we using?
d = 1;       # we nₐ buy shares of XYZ
nₐ = 1.0;    # how many shares do we want to buy, sell each day
δ = 0.50;    # z-score cutoff

# setup actions states -
actions = [1,2,3]  ; # buy, sell, hold
states = [1,2,3,4] ; # states defined below -

# parameters for the Q(s,a) estimation -
ϵ = 0.45;
number_of_trials = 500;

# %% [markdown]
# #### Define discrete state classes
# Let the state of our decision process be the share price of the underlying asset `XYZ`. However, the share price is (arguably) a continuous state variable, and we need to have discrete states. Toward this challenge, let's train a [Multiclass classifier](https://en.wikipedia.org/wiki/Multiclass_classification) that takes price as an input and gives back an integer class $\mathcal{C} = \left\{1,2,\dots,c\right\}$; where we build the following classes:
#
# * The share price $S_{t}$ belongs to `class 1` if it is close to an expected price $\mathbb{E}\left(S\right)$, but larger than the expected price $S_{t}>\mathbb{E}\left(S\right)$.
# * The share price $S_{t}$ belongs to `class 2` if it is much larger than an expected price $\mathbb{E}\left(S\right)$, i.e., $S_{t}\gg\mathbb{E}\left(S\right)$.
# * The share price $S_{t}$ belongs to `class 3` if it is close to an expected price $\mathbb{E}\left(S\right)$, but smaller than the expected price $S_{t}<\mathbb{E}\left(S\right)$.
# * The share price $S_{t}$ belongs to `class 4` if it is much smaller than an expected price $\mathbb{E}\left(S\right)$, i.e., $S_{t}\ll\mathbb{E}\left(S\right)$.
#
# The notion of `close`, `smaller` or `larger` needs to be more concrete; let's base these distances on the [z-score cutoff](https://en.wikipedia.org/wiki/Standard_score) parameter $\delta$ defined in the constants section.

# %%
# fit a distribution to vwap data -
normal_price_distribution = fit_mle(Normal, df_training[:,:volume_weighted_average_price]);

# get parameters -
θ = params(normal_price_distribution);

# setup price -
Sₒ = θ[1];
σ̂ = θ[2];

# print -
println("Long-term price of $(ticker_symbol) is Sₒ = $(Sₒ) USD/share with σ̂ = $(σ̂) USD/share")
# Out:
# Long-term price of AMD is Sₒ = 74.47168145933033 USD/share with σ̂ = 1.4059735498911663 USD/share

# %%
# build a labled training data set:
  
# initialize -
number_of_training_examples = nrow(df_training);
number_of_column_labels = 2
labeled_training_data = Array{Float64,2}(undef, number_of_training_examples,1);
label_array = Array{Int64,1}(undef, number_of_training_examples);

for i ∈ 1:number_of_training_examples
    
    # get the vwap -
    vwap_value = df_training[i,:volume_weighted_average_price]; #vwap = volume weighted average price
    labeled_training_data[i,1] = vwap_value;
    label_array[i] = state(vwap_value; μ = Sₒ, σ = σ̂, δ = δ)
end

# build a multiclass classifier -
mc_classifier_model = MultinomialRegression();
theta = MLJLinearModels.fit(mc_classifier_model, labeled_training_data, label_array);
W = reshape(theta,2,length(states));

# %% [markdown]
# ##### In-sample validation of the state classifier

# %%
# compute the percent correct classification in sample -
tmp_classification_array = Array{Int64,1}()
for i ∈ 1:number_of_training_examples
    
    predicted_state_class = state(labeled_training_data[i,1], W);
    actual_state_class = label_array[i];
    
    if (predicted_state_class == actual_state_class)
        push!(tmp_classification_array,1);
    else
        push!(tmp_classification_array,0);
    end
end

# how many 1's -
correct_classification_fraction = (1/number_of_training_examples)*sum(tmp_classification_array);

# correct -
println("In sample correct classification fraction: $(correct_classification_fraction)")
# Out:
# In sample correct classification fraction: 1.0

# %% [markdown]
# ##### Out-of-sample validation of the state classifier

# %%
# compute the percent correct classification in sample -
tmp_ous_classification_array = Array{Int64,1}()
number_of_prediction_examples = nrow(df_prediction);
for i ∈ 1:number_of_prediction_examples
    
    # grab the price -
    vwap_value = df_prediction[i,:volume_weighted_average_price];
    
    # compute the predicted class using the classifier -
    predicted_state_class = state(vwap_value, W);
    
    # compute the actual class using the manual method -
    actual_state_class = state(vwap_value; μ = Sₒ, σ = σ̂, δ = δ);
    
    if (predicted_state_class == actual_state_class)
        push!(tmp_ous_classification_array,1);
    else
        push!(tmp_ous_classification_array,0);
    end
end

# how many 1's -
correct_classification_ous_fraction = (1/number_of_prediction_examples)*sum(tmp_ous_classification_array);

# output -
println("Out of sample correct classification fraction: $(correct_classification_ous_fraction)")
# Out:
# Out of sample correct classification fraction: 1.0

# %% [markdown]
# #### Can we break the classifier?

# %%
# pick an index at random -
idx_quick_look = 41;

# grab the price -
vwap_value = df_prediction[idx_quick_look,:volume_weighted_average_price];
# vwap_value = df_training[idx_quick_look,:volume_weighted_average_price]; # look at training ...

# compute the predicted class using the classifier -
predicted_state_class = state(vwap_value, W);
    
# compute the actual class using the manual method -
actual_state_class = state(vwap_value; μ = Sₒ, σ = σ̂, δ = δ);

# println -
println("vwap = $(vwap_value) USD/share is class: $(actual_state_class) and predicted to be class: $(predicted_state_class)")
# Out:
# vwap = 73.5891 USD/share is class: 4 and predicted to be class: 4

# %% [markdown]
# ### Online estimation of the Q-table using Q-learning
# Now that we have our state classes (and our state classifier) let's turn our attention to the online estimation of the state-action-value matrix, otherwise known as the $ Q$ function. Imagine a scenario in which we don't know the transition matrix $T_{a}(s,s^{\prime})$ or the rewards array $R(s, a)$. Instead, we let our system learn by trying different actions in different states and seeing what reward we get. Thus, we allow our agent to learn by example.
#
# In this example, we allow the agent to execute random actions (exploration) or execute its best guess of the optimal move, and then we observe the reward received.
# * The action space in this example is $\mathcal{A}=\left\{\mathtt{buy}, \mathtt{sell}, \mathtt{hold}\right\}$; thus, we either buy $n_{a}$ shares of `XYZ`, sell $n_{a}$ shares of `XYZ` or do nothing.
# * The state space $\mathcal{S}$ is described above: $s_{1}$: current share close to but above some long-term expected price, $s_{2}$: current share price well above some long-term expected price, $s_{3}$: current share close to but below some long-term expected price and $s_{4}$: current share price well below some long-term expected price.
# * The reward we have chosen is the liquidation value on a per share basis of our position, i.e., what value could we get if we sold everything at the _next available market price_. In our case, we are using `5 min` data.
#
# #### Computational details
# * We do a random action $\epsilon$ of the time; otherwise, we let the agent execute its best estimate of the optimal action.
# * We run `number_of_trials`, collect the $Q$-function for each trial and estimate a policy $\pi(s)$ from the $Q(s, a)$ table for each trial.
# * After finishing `number_of_trials` and analyzing the data, we build a table with the recommended action for each state.
# * The update function was taken from `Algorithm 17.2` from [Kochenderfer et al. (2022)](https://algorithmsbook.com)
# * The current implementation of the code is slow. You've been warned.
#
# #### Interesting question:
# * I can imagine several `expert` policies, e.g., `buy the dip, sell the bounce`, a policy of 2,2,1,1. Alternatively, you could get `don't play small ball`, meaning wait for large swings to do anything (this has a policy of 3,2,3,1). Do we recover either of these policies?

# %%
# setup ϵ sim -
policy_array = Array{Int64,2}(undef, 4, number_of_trials);

# setup categorical distribution for drawing a random action -
action_distribution = Categorical([0.36,0.32,0.32]);

# initialize an empty ledger -
ledger_df = DataFrame(
    time = DateTime[],
    n = Float64[],
    price = Float64[],
    s = Int64[],
    action = Int64[]
);

for t ∈ 1:number_of_trials
    
    # clear the data frame -
    empty!(ledger_df);
    
    # initialize an empty Q -
    Q_array = Array{Float64,2}(undef, length(states), length(actions));
    fill!(Q_array, 0.0);
    
    # initial policy -> bias toward expert policy
    Q_array[1,2] = 10.0;
    Q_array[2,2] = 10.0;
    Q_array[3,1] = 10.0;
    Q_array[4,1] = 10.0;
    
    # build Q model -
    QMODEL = QLearningModel();
    QMODEL.γ = 0.75;
    QMODEL.α = 0.10;
    QMODEL.𝒮 = states;
    QMODEL.𝒜 = actions;
    QMODEL.Q = Q_array;
    
    # we buy 100 shares at initial price in the data -
    transaction = (
        time = df_training[1,:timestamp],
        n = 100.0,
        action = 1,
        price = price(df_training,1),
        s = state(price(df_training,1),W) 
    );
    push!(ledger_df, transaction)
    
    # main random simulation -
    for i ∈ 2:(nrow(df_training) - 1)

        # get data from the df_training -
        p = price(df_training, i);
        p′ = price(df_training, i+1);

        # convert that to the current state -
        s = state(p, W);
        s′ = state(p′, W);

        # roll a random number -
        aᵢ = 3; # default is to hold
        if (rand() <= ϵ)
            # roll a random action - 
            aᵢ = rand(action_distribution);
        else
            # ok, what action does my best guess say that I should take?
            policy = π(QMODEL.Q);
            aᵢ = policy[s];
        end
        
        # ok, if we have a sell, then we need to check to make sure we have the shares?
        total_number_of_shares_check = compute_position_size(ledger_df);
        if (aᵢ == 2 && total_number_of_shares_check < 10.0)
            
            # override - buy 1 shares -
            transaction = (
                time = df_training[i,:timestamp],
                n = 2,
                action = 1,
                price = p, 
                s = s
            );
            push!(ledger_df, transaction)
            
        else
            
            # build a transaction object -
            transaction = (
                time = df_training[i,:timestamp],
                n = nₐ,
                action = aᵢ,
                price = p, 
                s = s
            );
            push!(ledger_df, transaction)
        end
        
        # compute the total number of shares -
        total_number_of_shares = compute_position_size(ledger_df);
        
        if (total_number_of_shares < 0)
            @show total_number_of_shares
        end
        
        # we've update the ledger - compute the return per share if we sold everything at the price for the next time step -
        Rᵢ = -1*max(0,total_number_of_shares)*liquidate(ledger_df, p′);

        # update the QMODEL -
        update!(QMODEL, s, aᵢ, Rᵢ, s′);
    end
    
    pvec = π(Q_array)
    policy_array[1,t] = pvec[1]
    policy_array[2,t] = pvec[2]
    policy_array[3,t] = pvec[3]
    policy_array[4,t] = pvec[4]
end

# %%
# show the policy table -

# initialize -
policy_table_data_array = Array{Any,2}(undef, 4, 6);
for s ∈ 1:length(states)
    
    # compute -
    policy_table_data_array[s,1] = s;
    
    # compute the fraction of a₁, a₂ and a₃ -
    idx_a₁ = findall(x->x==1, policy_array[s,:]);
    idx_a₂ = findall(x->x==2, policy_array[s,:]);
    idx_a₃ = findall(x->x==3, policy_array[s,:]);
    
    # compute the fraction -
    policy_table_data_array[s,4] = (length(idx_a₁)/number_of_trials);
    policy_table_data_array[s,5] = (length(idx_a₂)/number_of_trials);
    policy_table_data_array[s,6] = (length(idx_a₃)/number_of_trials);
end

# put expert in -
policy_table_data_array[1,2] = 2;
policy_table_data_array[2,2] = 2;
policy_table_data_array[3,2] = 1;
policy_table_data_array[4,2] = 1;

# put recomended in -
policy_table_data_array[1,3] = argmax(softmax(Vector{Float64}(policy_table_data_array[1,4:end])));
policy_table_data_array[2,3] = argmax(softmax(Vector{Float64}(policy_table_data_array[2,4:end])));
policy_table_data_array[3,3] = argmax(softmax(Vector{Float64}(policy_table_data_array[3,4:end])));
policy_table_data_array[4,3] = argmax(softmax(Vector{Float64}(policy_table_data_array[4,4:end])));

# header -
header_data_policy_table = (
    ["Data (N=$(number_of_trials)): $(ticker_symbol) ", "", "", "", "", ""],
    ["s", "π(s)", "π̂(s)","a₁ (buy)", "a₂ (sell)", "a₃ (hold)"]
);

# display -
pretty_table(policy_table_data_array; header=header_data_policy_table)
# Out:
# ┌────────────────────┬──────┬──────┬──────────┬───────────┬───────────┐
# │ Data (N=500): AMD  │      │      │          │           │           │
# │                  s │ π(s) │ π̂(s) │ a₁ (buy) │ a₂ (sell) │ a₃ (hold) │
# ├────────────────────┼──────┼──────┼──────────┼───────────┼───────────┤
# │                  1 │    2 │    2 │    0.308 │      0.39 │     0.302 │
# │                  2 │    2 │    2 │    0.202 │      0.49 │     0.308 │
# │                  3 │    1 │    2 │    0.336 │      0.34 │     0.324 │
# │                  4 │    1 │    1 │    0.496 │     0.212 │     0.292 │
# └────────────────────┴──────┴──────┴──────────┴───────────┴───────────┘

# %% [markdown]
# __Table__: Recommended policy and the fraction of trials resulting in aᵢ for state s.

# %%
# build a local policy array -
local_policy_array = Array{Int64,1}(undef, length(states));
for s ∈ 1:length(states)
    local_policy_array[s] = policy_table_data_array[s,3]; # recommended policy is col 3
end

# save policy object so we can test later -
policy_model = build(TradeBotModel; policy = local_policy_array, ticker=ticker_symbol, W = W);

# dump policy_model to disk -
filename = "Policy-$(ticker_symbol)-Model-10.jld2";
save(joinpath("data",filename), Dict("model"=>policy_model))

# %%
# check:
for i ∈ 1:(nrow(df_training) - 1)
    
    total_number_of_shares = compute_position_size(ledger_df[1:i,:]);
    @show (i, total_number_of_shares)
    
end
# Out:
# (i, total_number_of_shares) = (1, 100)
# (i, total_number_of_shares) = (2, 99)
# (i, total_number_of_shares) = (3, 99)
# (i, total_number_of_shares) = (4, 100)
# (i, total_number_of_shares) = (5, 101)
# (i, total_number_of_shares) = (6, 102)
# (i, total_number_of_shares) = (7, 103)
# (i, total_number_of_shares) = (8, 102)
# (i, total_number_of_shares) = (9, 103)
# (i, total_number_of_shares) = (10, 102)
# (i, total_number_of_shares) = (11, 101)
# (i, total_number_of_shares) = (12, 101)
# (i, total_number_of_shares) = (13, 102)
# (i, total_number_of_shares) = (14, 102)
# (i, total_number_of_shares) = (15, 102)
# (i, total_number_of_shares) = (16, 101)
# (i, total_number_of_shares) = (17, 101)
# (i, total_number_of_shares) = (18, 100)
# (i, total_number_of_shares) = (19, 101)
# (i, total_number_of_shares) = (20, 100)
# (i, total_number_of_shares) = (21, 100)
# (i, total_number_of_shares) = (22, 101)
# (i, total_number_of_shares) = (23, 100)
# (i, total_number_of_shares) = (24, 101)
# (i, total_number_of_shares) = (25, 101)
# (i, total_number_of_shares) = (26, 101)
# (i, total_number_of_shares) = (27, 101)
# (i, total_number_of_shares) = (28, 100)
# (i, total_number_of_shares) = (29, 101)
# (i, total_number_of_shares) = (30, 100)
# (i, total_number_of_shares) = (31, 99)
# (i, total_number_of_shares) = (32, 99)
# (i, total_number_of_shares) = (33, 98)
# (i, total_number_of_shares) = (34, 97)
# (i, total_number_of_shares) = (35, 98)
# (i, total_number_of_shares) = (36, 98)
# (i, total_number_of_shares) = (37, 99)
# (i, total_number_of_shares) = (38, 100)
# (i, total_number_of_shares) = (39, 100)
# (i, total_number_of_shares) = (40, 99)
# (i, total_number_of_shares) = (41, 98)
# (i, total_number_of_shares) = (42, 98)
# (i, total_number_of_shares) = (43, 99)
# (i, total_number_of_shares) = (44, 99)
# (i, total_number_of_shares) = (45, 98)
# (i, total_number_of_shares) = (46, 99)
# (i, total_number_of_shares) = (47, 98)
# (i, total_number_of_shares) = (48, 98)
# (i, total_number_of_shares) = (49, 97)
# (i, total_number_of_shares) = (50, 98)
# (i, total_number_of_shares) = (51, 99)
# (i, total_number_of_shares) = (52, 98)
# (i, total_number_of_shares) = (53, 98)
# (i, total_number_of_shares) = (54, 98)
# (i, total_number_of_shares) = (55, 99)
# (i, total_number_of_shares) = (56, 99)
# (i, total_number_of_shares) = (57, 98)
# (i, total_number_of_shares) = (58, 98)
# (i, total_number_of_shares) = (59, 97)
# (i, total_number_of_shares) = (60, 98)
# (i, total_number_of_shares) = (61, 98)
# (i, total_number_of_shares) = (62, 98)
# (i, total_number_of_shares) = (63, 97)
# (i, total_number_of_shares) = (64, 97)
# (i, total_number_of_shares) = (65, 98)
# (i, total_number_of_shares) = (66, 99)
# (i, total_number_of_shares) = (67, 100)
# (i, total_number_of_shares) = (68, 101)
# (i, total_number_of_shares) = (69, 102)
# (i, total_number_of_shares) = (70, 102)
# (i, total_number_of_shares) = (71, 102)
# (i, total_number_of_shares) = (72, 102)
# (i, total_number_of_shares) = (73, 101)
# (i, total_number_of_shares) = (74, 102)
# (i, total_number_of_shares) = (75, 102)
# (i, total_number_of_shares) = (76, 103)
# (i, total_number_of_shares) = (77, 104)
# (i, total_number_of_shares) = (78, 105)
# (i, total_number_of_shares) = (79, 106)
# (i, total_number_of_shares) = (80, 107)
# (i, total_number_of_shares) = (81, 106)
# (i, total_number_of_shares) = (82, 107)
# (i, total_number_of_shares) = (83, 108)
# (i, total_number_of_shares) = (84, 109)
# (i, total_number_of_shares) = (85, 110)
# (i, total_number_of_shares) = (86, 111)
# (i, total_number_of_shares) = (87, 112)
# (i, total_number_of_shares) = (88, 113)
# (i, total_number_of_shares) = (89, 114)
# (i, total_number_of_shares) = (90, 115)
# (i, total_number_of_shares) = (91, 116)
# (i, total_number_of_shares) = (92, 117)
# (i, total_number_of_shares) = (93, 117)
# (i, total_number_of_shares) = (94, 116)
# (i, total_number_of_shares) = (95, 117)
# (i, total_number_of_shares) = (96, 117)
# (i, total_number_of_shares) = (97, 118)
# (i, total_number_of_shares) = (98, 119)
# (i, total_number_of_shares) = (99, 118)
# (i, total_number_of_shares) = (100, 117)
# (i, total_number_of_shares) = (101, 117)
# (i, total_number_of_shares) = (102, 116)
# (i, total_number_of_shares) = (103, 117)
# (i, total_number_of_shares) = (104, 116)
# (i, total_number_of_shares) = (105, 116)
# (i, total_number_of_shares) = (106, 115)
# (i, total_number_of_shares) = (107, 115)
# (i, total_number_of_shares) = (108, 116)
# (i, total_number_of_shares) = (109, 117)
# (i, total_number_of_shares) = (110, 116)
# (i, total_number_of_shares) = (111, 116)
# (i, total_number_of_shares) = (112, 115)
# (i, total_number_of_shares) = (113, 116)
# (i, total_number_of_shares) = (114, 115)
# (i, total_number_of_shares) = (115, 115)
# (i, total_number_of_shares) = (116, 115)
# (i, total_number_of_shares) = (117, 116)
# (i, total_number_of_shares) = (118, 116)
# (i, total_number_of_shares) = (119, 115)
# (i, total_number_of_shares) = (120, 114)
# (i, total_number_of_shares) = (121, 113)
# (i, total_number_of_shares) = (122, 114)
# (i, total_number_of_shares) = (123, 113)
# (i, total_number_of_shares) = (124, 113)
# (i, total_number_of_shares) = (125, 112)
# (i, total_number_of_shares) = (126, 111)
# (i, total_number_of_shares) = (127, 111)
# (i, total_number_of_shares) = (128, 112)
# (i, total_number_of_shares) = (129, 113)
# (i, total_number_of_shares) = (130, 113)
# (i, total_number_of_shares) = (131, 114)
# (i, total_number_of_shares) = (132, 114)
# (i, total_number_of_shares) = (133, 115)
# (i, total_number_of_shares) = (134, 116)
# (i, total_number_of_shares) = (135, 117)
# (i, total_number_of_shares) = (136, 118)
# (i, total_number_of_shares) = (137, 119)
# (i, total_number_of_shares) = (138, 120)
# (i, total_number_of_shares) = (139, 121)
# (i, total_number_of_shares) = (140, 120)
# (i, total_number_of_shares) = (141, 121)
# (i, total_number_of_shares) = (142, 120)
# (i, total_number_of_shares) = (143, 119)
# (i, total_number_of_shares) = (144, 119)
# (i, total_number_of_shares) = (145, 118)
# (i, total_number_of_shares) = (146, 119)
# (i, total_number_of_shares) = (147, 120)
# (i, total_number_of_shares) = (148, 119)
# (i, total_number_of_shares) = (149, 118)
# (i, total_number_of_shares) = (150, 117)
# (i, total_number_of_shares) = (151, 116)
# (i, total_number_of_shares) = (152, 115)
# (i, total_number_of_shares) = (153, 114)
# (i, total_number_of_shares) = (154, 113)
# (i, total_number_of_shares) = (155, 112)
# (i, total_number_of_shares) = (156, 112)
# (i, total_number_of_shares) = (157, 111)
# (i, total_number_of_shares) = (158, 110)
# (i, total_number_of_shares) = (159, 110)
# (i, total_number_of_shares) = (160, 109)
# (i, total_number_of_shares) = (161, 109)
# (i, total_number_of_shares) = (162, 110)
# (i, total_number_of_shares) = (163, 109)
# (i, total_number_of_shares) = (164, 108)
# (i, total_number_of_shares) = (165, 108)
# (i, total_number_of_shares) = (166, 107)
# (i, total_number_of_shares) = (167, 106)
# (i, total_number_of_shares) = (168, 105)
# (i, total_number_of_shares) = (169, 104)
# (i, total_number_of_shares) = (170, 103)
# (i, total_number_of_shares) = (171, 103)
# (i, total_number_of_shares) = (172, 103)
# (i, total_number_of_shares) = (173, 102)
# (i, total_number_of_shares) = (174, 103)
# (i, total_number_of_shares) = (175, 102)
# (i, total_number_of_shares) = (176, 103)
# (i, total_number_of_shares) = (177, 103)
# (i, total_number_of_shares) = (178, 103)
# (i, total_number_of_shares) = (179, 104)
# (i, total_number_of_shares) = (180, 105)
# (i, total_number_of_shares) = (181, 104)
# (i, total_number_of_shares) = (182, 103)
# (i, total_number_of_shares) = (183, 102)
# (i, total_number_of_shares) = (184, 103)
# (i, total_number_of_shares) = (185, 102)
# (i, total_number_of_shares) = (186, 101)
# (i, total_number_of_shares) = (187, 100)
# (i, total_number_of_shares) = (188, 101)
# (i, total_number_of_shares) = (189, 100)
# (i, total_number_of_shares) = (190, 101)
# (i, total_number_of_shares) = (191, 100)
# (i, total_number_of_shares) = (192, 101)
# (i, total_number_of_shares) = (193, 101)
# (i, total_number_of_shares) = (194, 101)
# (i, total_number_of_shares) = (195, 102)
# (i, total_number_of_shares) = (196, 103)
# (i, total_number_of_shares) = (197, 102)
# (i, total_number_of_shares) = (198, 103)
# (i, total_number_of_shares) = (199, 102)
# (i, total_number_of_shares) = (200, 103)
# (i, total_number_of_shares) = (201, 104)
# (i, total_number_of_shares) = (202, 104)
# (i, total_number_of_shares) = (203, 105)
# (i, total_number_of_shares) = (204, 106)
# (i, total_number_of_shares) = (205, 107)
# (i, total_number_of_shares) = (206, 108)
# (i, total_number_of_shares) = (207, 109)
# (i, total_number_of_shares) = (208, 110)
# (i, total_number_of_shares) = (209, 109)
# (i, total_number_of_shares) = (210, 110)
# (i, total_number_of_shares) = (211, 109)
# (i, total_number_of_shares) = (212, 110)
# (i, total_number_of_shares) = (213, 111)
# (i, total_number_of_shares) = (214, 110)
# (i, total_number_of_shares) = (215, 110)
# (i, total_number_of_shares) = (216, 109)
# (i, total_number_of_shares) = (217, 110)
# (i, total_number_of_shares) = (218, 111)
# (i, total_number_of_shares) = (219, 111)
# (i, total_number_of_shares) = (220, 111)
# (i, total_number_of_shares) = (221, 111)
# (i, total_number_of_shares) = (222, 110)
# (i, total_number_of_shares) = (223, 111)
# (i, total_number_of_shares) = (224, 110)
# (i, total_number_of_shares) = (225, 111)
# (i, total_number_of_shares) = (226, 110)
# (i, total_number_of_shares) = (227, 111)
# (i, total_number_of_shares) = (228, 111)
# (i, total_number_of_shares) = (229, 112)
# (i, total_number_of_shares) = (230, 112)
# (i, total_number_of_shares) = (231, 113)
# (i, total_number_of_shares) = (232, 112)
# (i, total_number_of_shares) = (233, 112)
# (i, total_number_of_shares) = (234, 112)
# (i, total_number_of_shares) = (235, 113)
# (i, total_number_of_shares) = (236, 112)
# (i, total_number_of_shares) = (237, 112)
# (i, total_number_of_shares) = (238, 113)
# (i, total_number_of_shares) = (239, 112)
# (i, total_number_of_shares) = (240, 112)
# (i, total_number_of_shares) = (241, 113)
# (i, total_number_of_shares) = (242, 112)
# (i, total_number_of_shares) = (243, 113)
# (i, total_number_of_shares) = (244, 113)
# (i, total_number_of_shares) = (245, 112)
# (i, total_number_of_shares) = (246, 111)
# (i, total_number_of_shares) = (247, 111)
# (i, total_number_of_shares) = (248, 111)
# (i, total_number_of_shares) = (249, 111)
# (i, total_number_of_shares) = (250, 110)
# (i, total_number_of_shares) = (251, 109)
# (i, total_number_of_shares) = (252, 110)
# (i, total_number_of_shares) = (253, 110)
# (i, total_number_of_shares) = (254, 111)
# (i, total_number_of_shares) = (255, 112)
# (i, total_number_of_shares) = (256, 113)
# (i, total_number_of_shares) = (257, 112)
# (i, total_number_of_shares) = (258, 112)
# (i, total_number_of_shares) = (259, 111)
# (i, total_number_of_shares) = (260, 112)
# (i, total_number_of_shares) = (261, 112)
# (i, total_number_of_shares) = (262, 113)
# (i, total_number_of_shares) = (263, 112)
# (i, total_number_of_shares) = (264, 111)
# (i, total_number_of_shares) = (265, 110)
# (i, total_number_of_shares) = (266, 110)
# (i, total_number_of_shares) = (267, 111)
# (i, total_number_of_shares) = (268, 112)
# (i, total_number_of_shares) = (269, 112)
# (i, total_number_of_shares) = (270, 111)
# (i, total_number_of_shares) = (271, 111)
# (i, total_number_of_shares) = (272, 112)
# (i, total_number_of_shares) = (273, 113)
# (i, total_number_of_shares) = (274, 112)
# (i, total_number_of_shares) = (275, 112)
# (i, total_number_of_shares) = (276, 113)
# (i, total_number_of_shares) = (277, 113)
# (i, total_number_of_shares) = (278, 112)
# (i, total_number_of_shares) = (279, 113)
# (i, total_number_of_shares) = (280, 112)
# (i, total_number_of_shares) = (281, 112)
# (i, total_number_of_shares) = (282, 113)
# (i, total_number_of_shares) = (283, 112)
# (i, total_number_of_shares) = (284, 112)
# (i, total_number_of_shares) = (285, 111)
# (i, total_number_of_shares) = (286, 112)
# (i, total_number_of_shares) = (287, 112)
# (i, total_number_of_shares) = (288, 113)
# (i, total_number_of_shares) = (289, 113)
# (i, total_number_of_shares) = (290, 114)
# (i, total_number_of_shares) = (291, 115)
# (i, total_number_of_shares) = (292, 114)
# (i, total_number_of_shares) = (293, 113)
# (i, total_number_of_shares) = (294, 113)
# (i, total_number_of_shares) = (295, 113)
# (i, total_number_of_shares) = (296, 113)
# (i, total_number_of_shares) = (297, 112)
# (i, total_number_of_shares) = (298, 113)
# (i, total_number_of_shares) = (299, 112)
# (i, total_number_of_shares) = (300, 112)
# (i, total_number_of_shares) = (301, 112)
# (i, total_number_of_shares) = (302, 111)
# (i, total_number_of_shares) = (303, 112)
# (i, total_number_of_shares) = (304, 113)
# (i, total_number_of_shares) = (305, 114)
# (i, total_number_of_shares) = (306, 115)
# (i, total_number_of_shares) = (307, 116)
# (i, total_number_of_shares) = (308, 115)
# (i, total_number_of_shares) = (309, 116)
# (i, total_number_of_shares) = (310, 117)
# (i, total_number_of_shares) = (311, 118)
# (i, total_number_of_shares) = (312, 117)
# (i, total_number_of_shares) = (313, 117)
# (i, total_number_of_shares) = (314, 118)
# (i, total_number_of_shares) = (315, 119)
# (i, total_number_of_shares) = (316, 118)
# (i, total_number_of_shares) = (317, 117)
# (i, total_number_of_shares) = (318, 116)
# (i, total_number_of_shares) = (319, 116)
# (i, total_number_of_shares) = (320, 115)
# (i, total_number_of_shares) = (321, 115)
# (i, total_number_of_shares) = (322, 115)
# (i, total_number_of_shares) = (323, 116)
# (i, total_number_of_shares) = (324, 115)
# (i, total_number_of_shares) = (325, 116)
# (i, total_number_of_shares) = (326, 115)
# (i, total_number_of_shares) = (327, 116)
# (i, total_number_of_shares) = (328, 116)
# (i, total_number_of_shares) = (329, 116)
# (i, total_number_of_shares) = (330, 115)
# (i, total_number_of_shares) = (331, 114)
# (i, total_number_of_shares) = (332, 115)
# (i, total_number_of_shares) = (333, 116)
# (i, total_number_of_shares) = (334, 116)
# (i, total_number_of_shares) = (335, 115)
# (i, total_number_of_shares) = (336, 114)
# (i, total_number_of_shares) = (337, 115)
# (i, total_number_of_shares) = (338, 115)
# (i, total_number_of_shares) = (339, 114)
# (i, total_number_of_shares) = (340, 115)
# (i, total_number_of_shares) = (341, 115)
# (i, total_number_of_shares) = (342, 114)
# (i, total_number_of_shares) = (343, 114)
# (i, total_number_of_shares) = (344, 115)
# (i, total_number_of_shares) = (345, 114)
# (i, total_number_of_shares) = (346, 115)
# (i, total_number_of_shares) = (347, 115)
# (i, total_number_of_shares) = (348, 114)
# (i, total_number_of_shares) = (349, 114)
# (i, total_number_of_shares) = (350, 113)
# (i, total_number_of_shares) = (351, 113)
# (i, total_number_of_shares) = (352, 114)
# (i, total_number_of_shares) = (353, 114)
# (i, total_number_of_shares) = (354, 113)
# (i, total_number_of_shares) = (355, 112)
# (i, total_number_of_shares) = (356, 111)
# (i, total_number_of_shares) = (357, 111)
# (i, total_number_of_shares) = (358, 111)
# (i, total_number_of_shares) = (359, 111)
# (i, total_number_of_shares) = (360, 111)
# (i, total_number_of_shares) = (361, 111)
# (i, total_number_of_shares) = (362, 111)
# (i, total_number_of_shares) = (363, 112)
# (i, total_number_of_shares) = (364, 113)
# (i, total_number_of_shares) = (365, 112)
# (i, total_number_of_shares) = (366, 113)
# (i, total_number_of_shares) = (367, 113)
# (i, total_number_of_shares) = (368, 113)
# (i, total_number_of_shares) = (369, 114)
# (i, total_number_of_shares) = (370, 114)
# (i, total_number_of_shares) = (371, 115)
# (i, total_number_of_shares) = (372, 114)
# (i, total_number_of_shares) = (373, 113)
# (i, total_number_of_shares) = (374, 113)
# (i, total_number_of_shares) = (375, 114)
# (i, total_number_of_shares) = (376, 115)
# (i, total_number_of_shares) = (377, 116)
# (i, total_number_of_shares) = (378, 117)
# (i, total_number_of_shares) = (379, 118)
# (i, total_number_of_shares) = (380, 119)
# (i, total_number_of_shares) = (381, 120)
# (i, total_number_of_shares) = (382, 121)
# (i, total_number_of_shares) = (383, 122)
# (i, total_number_of_shares) = (384, 123)
# (i, total_number_of_shares) = (385, 124)
# (i, total_number_of_shares) = (386, 125)
# (i, total_number_of_shares) = (387, 126)
# (i, total_number_of_shares) = (388, 126)
# (i, total_number_of_shares) = (389, 127)
# (i, total_number_of_shares) = (390, 128)
# (i, total_number_of_shares) = (391, 129)
# (i, total_number_of_shares) = (392, 130)
# (i, total_number_of_shares) = (393, 130)
# (i, total_number_of_shares) = (394, 131)
# (i, total_number_of_shares) = (395, 131)
# (i, total_number_of_shares) = (396, 132)
# (i, total_number_of_shares) = (397, 132)
# (i, total_number_of_shares) = (398, 133)
# (i, total_number_of_shares) = (399, 134)
# (i, total_number_of_shares) = (400, 135)
# (i, total_number_of_shares) = (401, 136)
# (i, total_number_of_shares) = (402, 137)
# (i, total_number_of_shares) = (403, 138)
# (i, total_number_of_shares) = (404, 139)
# (i, total_number_of_shares) = (405, 139)
# (i, total_number_of_shares) = (406, 139)
# (i, total_number_of_shares) = (407, 140)
# (i, total_number_of_shares) = (408, 140)
# (i, total_number_of_shares) = (409, 140)
# (i, total_number_of_shares) = (410, 141)
# (i, total_number_of_shares) = (411, 142)
# (i, total_number_of_shares) = (412, 143)
# (i, total_number_of_shares) = (413, 142)
# (i, total_number_of_shares) = (414, 143)
# (i, total_number_of_shares) = (415, 144)
# (i, total_number_of_shares) = (416, 145)
# (i, total_number_of_shares) = (417, 145)
# (i, total_number_of_shares) = (418, 146)
# (i, total_number_of_shares) = (419, 145)
# (i, total_number_of_shares) = (420, 146)
# (i, total_number_of_shares) = (421, 147)
# (i, total_number_of_shares) = (422, 147)
# (i, total_number_of_shares) = (423, 148)
# (i, total_number_of_shares) = (424, 149)
# (i, total_number_of_shares) = (425, 148)
# (i, total_number_of_shares) = (426, 149)
# (i, total_number_of_shares) = (427, 149)
# (i, total_number_of_shares) = (428, 149)
# (i, total_number_of_shares) = (429, 150)
# (i, total_number_of_shares) = (430, 151)
# (i, total_number_of_shares) = (431, 152)
# (i, total_number_of_shares) = (432, 153)
# (i, total_number_of_shares) = (433, 152)
# (i, total_number_of_shares) = (434, 152)
# (i, total_number_of_shares) = (435, 151)
# (i, total_number_of_shares) = (436, 150)
# (i, total_number_of_shares) = (437, 149)
# (i, total_number_of_shares) = (438, 148)
# (i, total_number_of_shares) = (439, 147)
# (i, total_number_of_shares) = (440, 146)
# (i, total_number_of_shares) = (441, 147)
# (i, total_number_of_shares) = (442, 147)
# (i, total_number_of_shares) = (443, 146)
# (i, total_number_of_shares) = (444, 147)
# (i, total_number_of_shares) = (445, 146)
# (i, total_number_of_shares) = (446, 145)
# (i, total_number_of_shares) = (447, 146)
# (i, total_number_of_shares) = (448, 146)
# (i, total_number_of_shares) = (449, 145)
# (i, total_number_of_shares) = (450, 144)
# (i, total_number_of_shares) = (451, 143)
# (i, total_number_of_shares) = (452, 142)
# (i, total_number_of_shares) = (453, 141)
# (i, total_number_of_shares) = (454, 140)
# (i, total_number_of_shares) = (455, 139)
# (i, total_number_of_shares) = (456, 138)
# (i, total_number_of_shares) = (457, 138)
# (i, total_number_of_shares) = (458, 137)
# (i, total_number_of_shares) = (459, 136)
# (i, total_number_of_shares) = (460, 135)
# (i, total_number_of_shares) = (461, 135)
# (i, total_number_of_shares) = (462, 134)
# (i, total_number_of_shares) = (463, 133)
# (i, total_number_of_shares) = (464, 132)
# (i, total_number_of_shares) = (465, 131)
# (i, total_number_of_shares) = (466, 130)
# (i, total_number_of_shares) = (467, 129)
# (i, total_number_of_shares) = (468, 128)
# (i, total_number_of_shares) = (469, 129)
# (i, total_number_of_shares) = (470, 128)
# (i, total_number_of_shares) = (471, 127)
# (i, total_number_of_shares) = (472, 126)
# (i, total_number_of_shares) = (473, 125)
# (i, total_number_of_shares) = (474, 125)
# (i, total_number_of_shares) = (475, 124)
# (i, total_number_of_shares) = (476, 123)
# (i, total_number_of_shares) = (477, 124)
# (i, total_number_of_shares) = (478, 123)
# (i, total_number_of_shares) = (479, 122)
# (i, total_number_of_shares) = (480, 121)
# (i, total_number_of_shares) = (481, 121)
# (i, total_number_of_shares) = (482, 120)
# (i, total_number_of_shares) = (483, 119)
# (i, total_number_of_shares) = (484, 118)
# (i, total_number_of_shares) = (485, 117)
# (i, total_number_of_shares) = (486, 116)
# (i, total_number_of_shares) = (487, 116)
# (i, total_number_of_shares) = (488, 115)
# (i, total_number_of_shares) = (489, 114)
# (i, total_number_of_shares) = (490, 113)
# (i, total_number_of_shares) = (491, 112)
# (i, total_number_of_shares) = (492, 113)
# (i, total_number_of_shares) = (493, 113)
# (i, total_number_of_shares) = (494, 114)
# (i, total_number_of_shares) = (495, 114)
# (i, total_number_of_shares) = (496, 113)
# (i, total_number_of_shares) = (497, 112)
# (i, total_number_of_shares) = (498, 111)
# (i, total_number_of_shares) = (499, 110)
# (i, total_number_of_shares) = (500, 109)
# (i, total_number_of_shares) = (501, 110)
# (i, total_number_of_shares) = (502, 109)
# (i, total_number_of_shares) = (503, 108)
# (i, total_number_of_shares) = (504, 107)
# (i, total_number_of_shares) = (505, 107)
# (i, total_number_of_shares) = (506, 107)
# (i, total_number_of_shares) = (507, 106)
# (i, total_number_of_shares) = (508, 106)
# (i, total_number_of_shares) = (509, 107)
# (i, total_number_of_shares) = (510, 106)
# (i, total_number_of_shares) = (511, 107)
# (i, total_number_of_shares) = (512, 106)
# (i, total_number_of_shares) = (513, 105)
# (i, total_number_of_shares) = (514, 104)
# (i, total_number_of_shares) = (515, 103)
# (i, total_number_of_shares) = (516, 104)
# (i, total_number_of_shares) = (517, 103)
# (i, total_number_of_shares) = (518, 102)
# (i, total_number_of_shares) = (519, 102)
# (i, total_number_of_shares) = (520, 101)
# (i, total_number_of_shares) = (521, 101)
# (i, total_number_of_shares) = (522, 102)
# (i, total_number_of_shares) = (523, 101)
# (i, total_number_of_shares) = (524, 100)
# (i, total_number_of_shares) = (525, 99)
# (i, total_number_of_shares) = (526, 98)
# (i, total_number_of_shares) = (527, 97)
# (i, total_number_of_shares) = (528, 96)
# (i, total_number_of_shares) = (529, 95)
# (i, total_number_of_shares) = (530, 94)
# (i, total_number_of_shares) = (531, 93)
# (i, total_number_of_shares) = (532, 94)
# (i, total_number_of_shares) = (533, 93)
# (i, total_number_of_shares) = (534, 92)
# (i, total_number_of_shares) = (535, 91)
# (i, total_number_of_shares) = (536, 90)
# (i, total_number_of_shares) = (537, 90)
# (i, total_number_of_shares) = (538, 91)
# (i, total_number_of_shares) = (539, 92)
# (i, total_number_of_shares) = (540, 91)
# (i, total_number_of_shares) = (541, 90)
# (i, total_number_of_shares) = (542, 89)
# (i, total_number_of_shares) = (543, 88)
# (i, total_number_of_shares) = (544, 87)
# (i, total_number_of_shares) = (545, 86)
# (i, total_number_of_shares) = (546, 85)
# (i, total_number_of_shares) = (547, 84)
# (i, total_number_of_shares) = (548, 84)
# (i, total_number_of_shares) = (549, 83)
# (i, total_number_of_shares) = (550, 83)
# (i, total_number_of_shares) = (551, 82)
# (i, total_number_of_shares) = (552, 81)
# (i, total_number_of_shares) = (553, 82)
# (i, total_number_of_shares) = (554, 81)
# (i, total_number_of_shares) = (555, 81)
# (i, total_number_of_shares) = (556, 80)
# (i, total_number_of_shares) = (557, 79)
# (i, total_number_of_shares) = (558, 78)
# (i, total_number_of_shares) = (559, 77)
# (i, total_number_of_shares) = (560, 76)
# (i, total_number_of_shares) = (561, 75)
# (i, total_number_of_shares) = (562, 74)
# (i, total_number_of_shares) = (563, 73)
# (i, total_number_of_shares) = (564, 72)
# (i, total_number_of_shares) = (565, 73)
# (i, total_number_of_shares) = (566, 72)
# (i, total_number_of_shares) = (567, 73)
# (i, total_number_of_shares) = (568, 72)
# (i, total_number_of_shares) = (569, 71)
# (i, total_number_of_shares) = (570, 70)
# (i, total_number_of_shares) = (571, 70)
# (i, total_number_of_shares) = (572, 69)
# (i, total_number_of_shares) = (573, 68)
# (i, total_number_of_shares) = (574, 69)
# (i, total_number_of_shares) = (575, 69)
# (i, total_number_of_shares) = (576, 69)
# (i, total_number_of_shares) = (577, 68)
# (i, total_number_of_shares) = (578, 68)
# (i, total_number_of_shares) = (579, 67)
# (i, total_number_of_shares) = (580, 67)
# (i, total_number_of_shares) = (581, 66)
# (i, total_number_of_shares) = (582, 66)
# (i, total_number_of_shares) = (583, 67)
# (i, total_number_of_shares) = (584, 68)
# (i, total_number_of_shares) = (585, 69)
# (i, total_number_of_shares) = (586, 68)
# (i, total_number_of_shares) = (587, 69)
# (i, total_number_of_shares) = (588, 68)
# (i, total_number_of_shares) = (589, 67)
# (i, total_number_of_shares) = (590, 66)
# (i, total_number_of_shares) = (591, 65)
# (i, total_number_of_shares) = (592, 65)
# (i, total_number_of_shares) = (593, 64)
# (i, total_number_of_shares) = (594, 63)
# (i, total_number_of_shares) = (595, 62)
# (i, total_number_of_shares) = (596, 62)
# (i, total_number_of_shares) = (597, 63)
# (i, total_number_of_shares) = (598, 62)
# (i, total_number_of_shares) = (599, 62)
# (i, total_number_of_shares) = (600, 61)
# (i, total_number_of_shares) = (601, 61)
# (i, total_number_of_shares) = (602, 60)
# (i, total_number_of_shares) = (603, 60)
# (i, total_number_of_shares) = (604, 59)
# (i, total_number_of_shares) = (605, 60)
# (i, total_number_of_shares) = (606, 60)
# (i, total_number_of_shares) = (607, 60)
# (i, total_number_of_shares) = (608, 61)
# (i, total_number_of_shares) = (609, 60)
# (i, total_number_of_shares) = (610, 60)
# (i, total_number_of_shares) = (611, 60)
# (i, total_number_of_shares) = (612, 60)
# (i, total_number_of_shares) = (613, 60)
# (i, total_number_of_shares) = (614, 60)
# (i, total_number_of_shares) = (615, 59)
# (i, total_number_of_shares) = (616, 59)
# (i, total_number_of_shares) = (617, 59)
# (i, total_number_of_shares) = (618, 59)
# (i, total_number_of_shares) = (619, 59)
# (i, total_number_of_shares) = (620, 59)
# (i, total_number_of_shares) = (621, 59)
# (i, total_number_of_shares) = (622, 58)
# (i, total_number_of_shares) = (623, 58)
# (i, total_number_of_shares) = (624, 57)
# (i, total_number_of_shares) = (625, 57)
# (i, total_number_of_shares) = (626, 57)
# (i, total_number_of_shares) = (627, 58)
# (i, total_number_of_shares) = (628, 57)
# (i, total_number_of_shares) = (629, 57)
# (i, total_number_of_shares) = (630, 57)
# (i, total_number_of_shares) = (631, 58)
# (i, total_number_of_shares) = (632, 58)
# (i, total_number_of_shares) = (633, 58)
# (i, total_number_of_shares) = (634, 59)
# (i, total_number_of_shares) = (635, 59)
# (i, total_number_of_shares) = (636, 58)
# (i, total_number_of_shares) = (637, 57)
# (i, total_number_of_shares) = (638, 57)
# (i, total_number_of_shares) = (639, 57)
# (i, total_number_of_shares) = (640, 57)
# (i, total_number_of_shares) = (641, 58)
# (i, total_number_of_shares) = (642, 58)
# (i, total_number_of_shares) = (643, 58)
# (i, total_number_of_shares) = (644, 57)
# (i, total_number_of_shares) = (645, 57)
# (i, total_number_of_shares) = (646, 57)
# (i, total_number_of_shares) = (647, 56)
# (i, total_number_of_shares) = (648, 55)
# (i, total_number_of_shares) = (649, 56)
# (i, total_number_of_shares) = (650, 57)
# (i, total_number_of_shares) = (651, 57)
# (i, total_number_of_shares) = (652, 56)
# (i, total_number_of_shares) = (653, 55)
# (i, total_number_of_shares) = (654, 54)
# (i, total_number_of_shares) = (655, 55)
# (i, total_number_of_shares) = (656, 54)
# (i, total_number_of_shares) = (657, 55)
# (i, total_number_of_shares) = (658, 54)
# (i, total_number_of_shares) = (659, 53)
# (i, total_number_of_shares) = (660, 52)
# (i, total_number_of_shares) = (661, 51)
# (i, total_number_of_shares) = (662, 51)
# (i, total_number_of_shares) = (663, 51)
# (i, total_number_of_shares) = (664, 51)
# (i, total_number_of_shares) = (665, 51)
# (i, total_number_of_shares) = (666, 51)
# (i, total_number_of_shares) = (667, 52)
# (i, total_number_of_shares) = (668, 53)
# (i, total_number_of_shares) = (669, 52)
# (i, total_number_of_shares) = (670, 51)
# (i, total_number_of_shares) = (671, 50)
# (i, total_number_of_shares) = (672, 49)
# (i, total_number_of_shares) = (673, 50)
# (i, total_number_of_shares) = (674, 51)
# (i, total_number_of_shares) = (675, 51)
# (i, total_number_of_shares) = (676, 50)
# (i, total_number_of_shares) = (677, 49)
# (i, total_number_of_shares) = (678, 48)
# (i, total_number_of_shares) = (679, 47)
# (i, total_number_of_shares) = (680, 47)
# (i, total_number_of_shares) = (681, 47)
# (i, total_number_of_shares) = (682, 46)
# (i, total_number_of_shares) = (683, 45)
# (i, total_number_of_shares) = (684, 46)
# (i, total_number_of_shares) = (685, 47)
# (i, total_number_of_shares) = (686, 48)
# (i, total_number_of_shares) = (687, 49)
# (i, total_number_of_shares) = (688, 50)
# (i, total_number_of_shares) = (689, 49)
# (i, total_number_of_shares) = (690, 50)
# (i, total_number_of_shares) = (691, 50)
# (i, total_number_of_shares) = (692, 49)
# (i, total_number_of_shares) = (693, 50)
# (i, total_number_of_shares) = (694, 50)
# (i, total_number_of_shares) = (695, 49)
# (i, total_number_of_shares) = (696, 48)
# (i, total_number_of_shares) = (697, 47)
# (i, total_number_of_shares) = (698, 48)
# (i, total_number_of_shares) = (699, 49)
# (i, total_number_of_shares) = (700, 49)
# (i, total_number_of_shares) = (701, 50)
# (i, total_number_of_shares) = (702, 50)
# (i, total_number_of_shares) = (703, 49)
# (i, total_number_of_shares) = (704, 50)
# (i, total_number_of_shares) = (705, 51)
# (i, total_number_of_shares) = (706, 52)
# (i, total_number_of_shares) = (707, 52)
# (i, total_number_of_shares) = (708, 51)
# (i, total_number_of_shares) = (709, 52)
# (i, total_number_of_shares) = (710, 53)
# (i, total_number_of_shares) = (711, 52)
# (i, total_number_of_shares) = (712, 52)
# (i, total_number_of_shares) = (713, 51)
# (i, total_number_of_shares) = (714, 52)
# (i, total_number_of_shares) = (715, 53)
# (i, total_number_of_shares) = (716, 53)
# (i, total_number_of_shares) = (717, 52)
# (i, total_number_of_shares) = (718, 52)
# (i, total_number_of_shares) = (719, 52)
# (i, total_number_of_shares) = (720, 51)
# (i, total_number_of_shares) = (721, 50)
# (i, total_number_of_shares) = (722, 49)
# (i, total_number_of_shares) = (723, 49)
# (i, total_number_of_shares) = (724, 48)
# (i, total_number_of_shares) = (725, 48)
# (i, total_number_of_shares) = (726, 49)
# (i, total_number_of_shares) = (727, 48)
# (i, total_number_of_shares) = (728, 47)
# (i, total_number_of_shares) = (729, 46)
# (i, total_number_of_shares) = (730, 46)
# (i, total_number_of_shares) = (731, 45)
# (i, total_number_of_shares) = (732, 44)
# (i, total_number_of_shares) = (733, 43)
# (i, total_number_of_shares) = (734, 44)
# (i, total_number_of_shares) = (735, 45)
# (i, total_number_of_shares) = (736, 45)
# (i, total_number_of_shares) = (737, 44)
# (i, total_number_of_shares) = (738, 43)
# (i, total_number_of_shares) = (739, 42)
# (i, total_number_of_shares) = (740, 41)
# (i, total_number_of_shares) = (741, 40)
# (i, total_number_of_shares) = (742, 39)
# (i, total_number_of_shares) = (743, 38)
# (i, total_number_of_shares) = (744, 37)
# (i, total_number_of_shares) = (745, 36)
# (i, total_number_of_shares) = (746, 37)
# (i, total_number_of_shares) = (747, 38)
# (i, total_number_of_shares) = (748, 37)
# (i, total_number_of_shares) = (749, 36)
# (i, total_number_of_shares) = (750, 35)
# (i, total_number_of_shares) = (751, 34)
# (i, total_number_of_shares) = (752, 34)
# (i, total_number_of_shares) = (753, 34)
# (i, total_number_of_shares) = (754, 34)
# (i, total_number_of_shares) = (755, 34)
# (i, total_number_of_shares) = (756, 33)
# (i, total_number_of_shares) = (757, 32)
# (i, total_number_of_shares) = (758, 31)
# (i, total_number_of_shares) = (759, 30)
# (i, total_number_of_shares) = (760, 29)
# (i, total_number_of_shares) = (761, 28)
# (i, total_number_of_shares) = (762, 27)
# (i, total_number_of_shares) = (763, 27)
# (i, total_number_of_shares) = (764, 26)
# (i, total_number_of_shares) = (765, 25)
# (i, total_number_of_shares) = (766, 24)
# (i, total_number_of_shares) = (767, 23)
# (i, total_number_of_shares) = (768, 22)
# (i, total_number_of_shares) = (769, 23)
# (i, total_number_of_shares) = (770, 24)
# (i, total_number_of_shares) = (771, 23)
# (i, total_number_of_shares) = (772, 22)
# (i, total_number_of_shares) = (773, 21)
# (i, total_number_of_shares) = (774, 20)
# (i, total_number_of_shares) = (775, 19)
# (i, total_number_of_shares) = (776, 18)
# (i, total_number_of_shares) = (777, 17)
# (i, total_number_of_shares) = (778, 16)
# (i, total_number_of_shares) = (779, 17)
# (i, total_number_of_shares) = (780, 18)
# (i, total_number_of_shares) = (781, 18)
# (i, total_number_of_shares) = (782, 18)
# (i, total_number_of_shares) = (783, 19)
# (i, total_number_of_shares) = (784, 20)
# (i, total_number_of_shares) = (785, 19)
# (i, total_number_of_shares) = (786, 20)
# (i, total_number_of_shares) = (787, 21)
# (i, total_number_of_shares) = (788, 21)
# (i, total_number_of_shares) = (789, 22)
# (i, total_number_of_shares) = (790, 21)
# (i, total_number_of_shares) = (791, 22)
# (i, total_number_of_shares) = (792, 21)
# (i, total_number_of_shares) = (793, 21)
# (i, total_number_of_shares) = (794, 22)
# (i, total_number_of_shares) = (795, 23)
# (i, total_number_of_shares) = (796, 22)
# (i, total_number_of_shares) = (797, 23)
# (i, total_number_of_shares) = (798, 23)
# (i, total_number_of_shares) = (799, 22)
# (i, total_number_of_shares) = (800, 21)
# (i, total_number_of_shares) = (801, 22)
# (i, total_number_of_shares) = (802, 23)
# (i, total_number_of_shares) = (803, 24)
# (i, total_number_of_shares) = (804, 25)
# (i, total_number_of_shares) = (805, 26)
# (i, total_number_of_shares) = (806, 27)
# (i, total_number_of_shares) = (807, 26)
# (i, total_number_of_shares) = (808, 27)
# (i, total_number_of_shares) = (809, 27)
# (i, total_number_of_shares) = (810, 28)
# (i, total_number_of_shares) = (811, 28)
# (i, total_number_of_shares) = (812, 29)
# (i, total_number_of_shares) = (813, 29)
# (i, total_number_of_shares) = (814, 28)
# (i, total_number_of_shares) = (815, 28)
# (i, total_number_of_shares) = (816, 27)
# (i, total_number_of_shares) = (817, 27)
# (i, total_number_of_shares) = (818, 26)
# (i, total_number_of_shares) = (819, 26)
# (i, total_number_of_shares) = (820, 26)
# (i, total_number_of_shares) = (821, 25)
# (i, total_number_of_shares) = (822, 25)
# (i, total_number_of_shares) = (823, 24)
# (i, total_number_of_shares) = (824, 24)
# (i, total_number_of_shares) = (825, 23)
# (i, total_number_of_shares) = (826, 23)
# (i, total_number_of_shares) = (827, 24)
# (i, total_number_of_shares) = (828, 23)
# (i, total_number_of_shares) = (829, 23)
# (i, total_number_of_shares) = (830, 24)
# (i, total_number_of_shares) = (831, 23)
# (i, total_number_of_shares) = (832, 24)
# (i, total_number_of_shares) = (833, 24)
# (i, total_number_of_shares) = (834, 25)
# (i, total_number_of_shares) = (835, 24)

# %% [markdown]
# ### Additional Resources
# * [Chapter 17: Mykel J. Kochenderfer, Tim A. Wheeler, Kyle H. Wray "Algorithms for Decision Making", MIT Press 2022](https://algorithmsbook.com)

# %% [markdown]
# ### Disclaimer and Risks
# __This content is offered solely for training and  informational purposes__. No offer or solicitation to buy or sell securities or derivative products, or any investment or trading advice or strategy,  is made, given, or endorsed by the teaching team.
#
# __Trading involves risk__. Carefully review your financial situation before investing in securities, futures contracts, options, or commodity interests. Past performance, whether actual or indicated by historical tests of strategies, is no guarantee of future performance or success. Trading is generally inappropriate for someone with limited resources, investment or trading experience, or a low-risk tolerance.  Only risk capital that is not required for living expenses.
#
# __You are fully responsible for any investment or trading decisions you make__. Such decisions should be based solely on your evaluation of your financial circumstances, investment or trading objectives, risk tolerance, and liquidity needs.
